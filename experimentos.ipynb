# %% [markdown]
# # EXPERIMENTACIÓN

# %%
import os

os.system("pip install -r requirements.txt")
print("Librerías instaladas.")
# Out:
# Librerías instaladas.

# %% [markdown]
# En este Jupyter notebook se llevaron a cabo los experimentos con las matrices proporcionadas en el plantemiento del problema.

# %%
# Importamos los módulos necesarios
from src.poly_car import *
from src.powermethod import *
from src.qrDecomposition import QRDecomposition
import numpy as np

# %%
# Guardamos las matrices en un diccionario para facilitar el acceso.
matrices = {
    'A': np.matrix([[2,1],[3,4]]),
    'B': np.matrix([[3,2],[3,4]]),
    'C': np.matrix([[2,3],[1,4]]),
    'D': np.matrix([[1,1,2],[2,1,1],[1,1,3]]),
    'E': np.matrix([[1,1,2],[2,1,3],[1,1,1]]),
    'F': np.matrix([[2,1,2],[1,1,3],[1,1,1]]),
    'G': np.matrix([[1,1,1,2],[2,1,1,1],[3,2,1,2],[2,1,1,4]]),
    'H': np.matrix([[1,2,1,2],[2,1,1,1],[3,2,1,2],[2,1,1,4]])
}

# %% [markdown]
# # A

# %% [markdown]
# $$
#     \mathbf{A} = \begin{bmatrix}
#     2 & 1 \\
#     3 & 4
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['A'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[2.00, 1.00], [3.00, 4.00]])
#
# El polinomio característico de la matriz es:
#  2
# λ  - 6⋅λ + 5
#
# Raíces encontradas = Valores propios encontrados: {0.999999999996362, 5}
# {0.999999999996362, 5}

# %%
power_method(matrices['A'])
# Out:
# (np.float64(5.000000183872821), array([0.31622778, 0.94868329]))

# %%
QRDecomposition(matrices['A']).main()
# Out:
# Valores propios encontrados:
# 	1.0, 5.0.
# [1.0000000000000009, 4.999999999999999]

# %% [markdown]
# Cada método encontró los mismos valores propios: 1 y 5.

# %% [markdown]
# # B

# %% [markdown]
# $$
#     \mathbf{B} = \begin{bmatrix}
#     3 & 2 \\
#     3 & 4
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['B'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[3.00, 2.00], [3.00, 4.00]])
#
# El polinomio característico de la matriz es:
#  2
# λ  - 7⋅λ + 6
#
# Raíces encontradas = Valores propios encontrados: {0.999999999997090}
# {0.999999999997090}

# %%
power_method(matrices['B'])
# Out:
# (np.float64(6.000000084528222), array([0.55470021, 0.83205029]))

# %%
QRDecomposition(matrices['B']).main()
# Out:
# Valores propios encontrados:
# 	1.0, 6.0.
# [0.9999999999999991, 6.000000000000001]

# %% [markdown]
# # C

# %% [markdown]
# $$
#     \mathbf{C} = \begin{bmatrix}
#     2 & 3 \\
#     1 & 4
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['C'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[2.00, 3.00], [1.00, 4.00]])
#
# El polinomio característico de la matriz es:
#  2
# λ  - 6⋅λ + 5
#
# Raíces encontradas = Valores propios encontrados: {0.999999999996362, 5}
# {0.999999999996362, 5}

# %%
power_method(matrices['C'])
# Out:
# (np.float64(5.000000121280466), array([0.70710677, 0.70710679]))

# %%
QRDecomposition(matrices['C']).main()
# Out:
# Valores propios encontrados:
# 	1.0, 5.0.
# [0.9999999999999982, 5.000000000000002]

# %% [markdown]
# # D

# %% [markdown]
# $$
#     \mathbf{D} = \begin{bmatrix}
#     1 & 1 & 2 \\
#     2 & 1 & 1 \\
#     1 & 1 & 3
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['D'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[1.00, 1.00, 2.00], [2.00, 1.00, 1.00], [1.00, 1.00, 3.00]])
#
# El polinomio característico de la matriz es:
#    3      2
# - λ  + 5⋅λ  - 2⋅λ - 1
#
# Raíces encontradas = Valores propios encontrados: {0.778123837739209}
# {0.778123837739209}

# %%
power_method(matrices['D'])
# Out:
# (np.float64(4.50701853680364), array([0.53231709, 0.49863936, 0.68410329]))

# %%
QRDecomposition(matrices['D']).main()
# Out:
# Valores propios aproxiamdos:
# 	0.92, -0.43, 4.51.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 QRDecomposition(matrices['D']).main()
#
# File c:\Users\jprmg\Desktop\Hernandez-Montoya-Mora-Robledo-Usuga\src\qrDecomposition.py:85, in QRDecomposition.main(self)
#      83 print("Valores propios aproxiamdos:")
#      84 print(f"\t{', '.join([str(round(e, 2)) for e in eigenvalues])}.")
# ---> 85 raise Exception("ERROR: El método no converge para esta matriz.")
#
# Exception: ERROR: El método no converge para esta matriz.

# %% [markdown]
# # E

# %% [markdown]
# $$
#     \mathbf{E} = \begin{bmatrix}
#     1 & 1 & 2 \\
#     2 & 1 & 3 \\
#     1 & 1 & 1
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['E'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[1.00, 1.00, 2.00], [2.00, 1.00, 3.00], [1.00, 1.00, 1.00]])
#
# El polinomio característico de la matriz es:
#    3      2
# - λ  + 3⋅λ  + 4⋅λ + 1
#
# Raíces encontradas = Valores propios encontrados: {4.04891733952470}
# {4.04891733952470}

# %%
power_method(matrices['E'])
# Out:
# (np.float64(4.048917213547326), array([0.51769363, 0.74808896, 0.41515806]))

# %%
QRDecomposition(matrices['E']).main()
# Out:
# Valores propios aproxiamdos:
# 	-0.69, -0.36, 4.05.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 QRDecomposition(matrices['E']).main()
#
# File c:\Users\jprmg\Desktop\Hernandez-Montoya-Mora-Robledo-Usuga\src\qrDecomposition.py:85, in QRDecomposition.main(self)
#      83 print("Valores propios aproxiamdos:")
#      84 print(f"\t{', '.join([str(round(e, 2)) for e in eigenvalues])}.")
# ---> 85 raise Exception("ERROR: El método no converge para esta matriz.")
#
# Exception: ERROR: El método no converge para esta matriz.

# %% [markdown]
# # F

# %% [markdown]
# $$
#     \mathbf{F} = \begin{bmatrix}
#     2 & 1 & 2 \\
#     1 & 1 & 3 \\
#     1 & 1 & 1
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['F'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[2.00, 1.00, 2.00], [1.00, 1.00, 3.00], [1.00, 1.00, 1.00]])
#
# El polinomio característico de la matriz es:
#    3      2
# - λ  + 4⋅λ  + λ - 2
#
# Raíces encontradas = Valores propios encontrados: {0.636671762067945}
# {0.636671762067945}

# %%
power_method(matrices['F'])
# Out:
# (np.float64(4.124885473232469), array([0.67550236, 0.61159354, 0.41188579]))

# %%
QRDecomposition(matrices['F']).main()
# Out:
# Valores propios aproxiamdos:
# 	-0.76, 0.64, 4.12.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 QRDecomposition(matrices['F']).main()
#
# File c:\Users\jprmg\Desktop\Hernandez-Montoya-Mora-Robledo-Usuga\src\qrDecomposition.py:85, in QRDecomposition.main(self)
#      83 print("Valores propios aproxiamdos:")
#      84 print(f"\t{', '.join([str(round(e, 2)) for e in eigenvalues])}.")
# ---> 85 raise Exception("ERROR: El método no converge para esta matriz.")
#
# Exception: ERROR: El método no converge para esta matriz.

# %% [markdown]
# # G

# %% [markdown]
# $$
#     \mathbf{G} = \begin{bmatrix}
#     1 & 1 & 1 & 2 \\
#     2 & 1 & 1 & 1 \\
#     3 & 2 & 1 & 2 \\
#     2 & 1 & 1 & 4
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['G'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[1.00, 1.00, 1.00, 2.00], [2.00, 1.00, 1.00, 1.00], [3.00, 2.00, 1.00, 2.00], [2.00, 1.00, 1.00, 4.00]])
#
# El polinomio característico de la matriz es:
#  4      3    2
# λ  - 7⋅λ  + λ  + 9⋅λ + 3
#
# Raíces encontradas = Valores propios encontrados: {1.50856334494531}
# {1.50856334494531}

# %%
power_method(matrices['G'])
# Out:
# (np.float64(6.634534308321676),
#  array([0.38941594, 0.35142165, 0.55977508, 0.64149038]))

# %%
QRDecomposition(matrices['G']).main()
# Out:
# Valores propios aproxiamdos:
# 	-0.74, 1.51, -0.41, 6.63.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 QRDecomposition(matrices['G']).main()
#
# File c:\Users\jprmg\Desktop\Hernandez-Montoya-Mora-Robledo-Usuga\src\qrDecomposition.py:85, in QRDecomposition.main(self)
#      83 print("Valores propios aproxiamdos:")
#      84 print(f"\t{', '.join([str(round(e, 2)) for e in eigenvalues])}.")
# ---> 85 raise Exception("ERROR: El método no converge para esta matriz.")
#
# Exception: ERROR: El método no converge para esta matriz.

# %% [markdown]
# # H

# %% [markdown]
# $$
#     \mathbf{H} = \begin{bmatrix}
#     1 & 2 & 1 & 2 \\
#     2 & 1 & 1 & 1 \\
#     3 & 2 & 1 & 2 \\
#     2 & 1 & 1 & 4
#     \end{bmatrix}
# $$

# %%
encontrar_raices_biseccion_newton(matrices['H'], 0, 5)
# Out:
# Matriz ingresada (redondeada):
# Matrix([[1.00, 2.00, 1.00, 2.00], [2.00, 1.00, 1.00, 1.00], [3.00, 2.00, 1.00, 2.00], [2.00, 1.00, 1.00, 4.00]])
#
# El polinomio característico de la matriz es:
#  4      3    2
# λ  - 7⋅λ  - λ  + 14⋅λ + 6
#
# Raíces encontradas = Valores propios encontrados: {1.72811590829006}
# {1.72811590829006}

# %%
power_method(matrices['H'])
# Out:
# (np.float64(6.827262443320049),
#  array([0.42853132, 0.34899465, 0.55406664, 0.62255426]))

# %%
QRDecomposition(matrices['H']).main()
# Out:
# Valores propios aproxiamdos:
# 	-1.09, 1.66, -0.4, 6.83.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 QRDecomposition(matrices['H']).main()
#
# File c:\Users\jprmg\Desktop\Hernandez-Montoya-Mora-Robledo-Usuga\src\qrDecomposition.py:85, in QRDecomposition.main(self)
#      83 print("Valores propios aproxiamdos:")
#      84 print(f"\t{', '.join([str(round(e, 2)) for e in eigenvalues])}.")
# ---> 85 raise Exception("ERROR: El método no converge para esta matriz.")
#
# Exception: ERROR: El método no converge para esta matriz.
